# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}

# %%
import pandas as pd
df = pd.read_csv('../data/gunshot.csv')
df['Poverty rate'] = df['Poverty rate'].str.rstrip('%').astype('float') / 100.0
df['Permit required to carry handgun'] = df['Permit required to carry handgun']#.replace('No',-1).replace('Yes',1).replace('FOID',0)
df.insert(loc=0, column='code', value=[us_state_abbrev[i] for i in df['State']])
df
# Out:
#    code           State  Firearm deaths per 100,000 people  Poverty rate  \
# 0    MS     Mississippi                               19.8         0.208
# 1    OK        Oklahoma                               19.6         0.163
# 2    DE        Delaware                               10.9         0.117
# 3    MN       Minnesota                                7.6         0.099
# 4    AK          Alaska                               23.0         0.099
# 5    IL        Illinois                               11.6         0.130
# 6    AR        Arkansas                               17.7         0.172
# 7    NM      New Mexico                               18.2         0.198
# 8    OH            Ohio                               12.9         0.146
# 9    IN         Indiana                               14.9         0.141
# 10   MD        Maryland                               11.8         0.097
# 11   LA       Louisiana                               21.2         0.202
# 12   TX           Texas                               12.1         0.156
# 13   WY         Wyoming                               17.5         0.113
# 14   AZ         Arizona                               15.2         0.164
# 15   WI       Wisconsin                               11.4         0.118
# 16   MI        Michigan                               12.2         0.150
# 17   KS          Kansas                               13.3         0.121
# 18   UT            Utah                               12.9         0.102
# 19   VA        Virginia                               12.0         0.110
# 20   OR          Oregon                               11.8         0.133
# 21   CT     Connecticut                                4.6         0.098
# 22   TN       Tennessee                               17.0         0.158
# 23   CA      California                                7.9         0.143
# 24   MA   Massachusetts                                3.4         0.104
# 25   WV   West Virginia                               17.5         0.179
# 26   SC  South Carolina                               17.7         0.153
# 27   NH   New Hampshire                                9.3         0.073
# 28   VT         Vermont                               11.0         0.119
# 29   GA         Georgia                               14.9         0.160
# 30   ND    North Dakota                               11.9         0.107
# 31   PA    Pennsylvania                               11.9         0.129
# 32   FL         Florida                               12.6         0.147
# 33   HI          Hawaii                                4.5         0.093
# 34   KY        Kentucky                               17.5         0.185
# 35   RI    Rhode Island                                4.0         0.128
# 36   NE        Nebraska                                9.1         0.114
# 37   MO        Missouri                               18.8         0.140
# 38   IA            Iowa                                9.2         0.118
# 39   AL         Alabama                               21.4         0.171
# 40   SD    South Dakota                               13.5         0.133
# 41   CO        Colorado                               14.3         0.110
# 42   ID           Idaho                               14.6         0.144
# 43   NJ      New Jersey                                5.5         0.104
# 44   WA      Washington                                9.0         0.113
# 45   NC  North Carolina                               13.6         0.154
# 46   NY        New York                                4.4         0.147
# 47   MT         Montana                               19.0         0.133
# 48   NV          Nevada                               16.7         0.138
# 49   ME           Maine                                8.2         0.125
#
#    Permit required to carry handgun  Violent crime rate  \
# 0                                No               280.5
# 1                               Yes               449.8
# 2                               Yes               508.8
# 3                               Yes               242.6
# 4                                No               804.2
# 5                              FOID               436.3
# 6                               Yes               550.9
# 7                               Yes               702.5
# 8                               Yes               300.3
# 9                               Yes               404.7
# 10                              Yes               472.0
# 11                              Yes               566.1
# 12                              Yes               434.4
# 13                               No               244.2
# 14                               No               470.1
# 15                              Yes               305.9
# 16                              Yes               459.0
# 17                               No               380.4
# 18                              Yes               242.8
# 19                              Yes               217.6
# 20                              Yes               264.6
# 21                              Yes               227.1
# 22                              Yes               632.9
# 23                              Yes               445.3
# 24                              Yes               376.9
# 25                               No               358.1
# 26                              Yes               501.8
# 27                               No               197.6
# 28                               No               158.3
# 29                              Yes               397.6
# 30                               No               251.1
# 31                              Yes               316.4
# 32                              Yes               430.3
# 33                              Yes               309.2
# 34                              Yes               232.3
# 35                              Yes               238.9
# 36                              Yes               291.0
# 37                               No               519.4
# 38                              Yes               290.6
# 39                              Yes               532.3
# 40                              Yes               418.4
# 41                              Yes               342.6
# 42                               No               230.3
# 43                              Yes               245.0
# 44                              Yes               302.2
# 45                              Yes               372.2
# 46                              Yes               376.2
# 47                              Yes               368.3
# 48                              Yes               678.1
# 49                               No               123.8
#
#     Total firearm deaths 2016
# 0                         587
# 1                         766
# 2                         111
# 3                         432
# 4                         177
# 5                        1490
# 6                         541
# 7                         383
# 8                        1524
# 9                         997
# 10                        707
# 11                        987
# 12                       3353
# 13                        101
# 14                       1094
# 15                        664
# 16                       1230
# 17                        383
# 18                        370
# 19                       1049
# 20                        513
# 21                        172
# 22                       1148
# 23                       3184
# 24                        242
# 25                        332
# 26                        891
# 27                        132
# 28                         78
# 29                       1571
# 30                         90
# 31                       1555
# 32                       2704
# 33                         66
# 34                        772
# 35                         49
# 36                        171
# 37                       1144
# 38                        288
# 39                       1046
# 40                        108
# 41                        812
# 42                        242
# 43                        485
# 44                        686
# 45                       1409
# 46                        900
# 47                        194
# 48                        498
# 49                        123

# %%
import seaborn as sns
# g = sns.pairplot(df)
g = sns.pairplot(df, hue = 'Permit required to carry handgun')

# %%
import plotly
import plotly.plotly as py
import pandas as pd
# plotly.tools.set_credentials_file(username='shl666', api_key='63b9Xz7eRm7yqi5GrSK2')
def mapPlot(df, item):
    for col in df.columns:
        df[col] = df[col].astype(str)

    scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
                [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]


    data = [ dict(
            type='choropleth',
            colorscale = scl,
            autocolorscale = False,
            locations = df['code'],
            z = df[item].astype(float),
            locationmode = 'USA-states',
            marker = dict(
                line = dict (
                    color = 'rgb(255,255,255)',
                    width = 2
                ) )
            ) ]

    layout = dict(
            title = '2016 US {}'.format(item),
            geo = dict(
                scope='usa',
                projection=dict( type='albers usa' ),
                showlakes = True,
                lakecolor = 'rgb(255, 255, 255)'),
                 )

    fig = dict( data=data, layout=layout )
    res = py.iplot( fig, filename='d3-cloropleth-map' )
    return res

# %%
res = mapPlot(df, 'Poverty rate')
res
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~shl666/0 or inside your plot.ly account where it is named 'd3-cloropleth-map'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~shl666/0.embed" height="525px" width="100%"></iframe>
