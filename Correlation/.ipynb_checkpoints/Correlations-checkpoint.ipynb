# %%
import pandas
import plotly
import plotly.plotly as py
import locale
from locale import atof

# %%
def gunshot_data_fetch():
    
    import pandas as pd
    us_state_abbrev = {
        'Alabama': 'AL','Alaska': 'AK','Arizona': 'AZ','Arkansas': 'AR','California': 'CA','Colorado': 'CO',
        'Connecticut': 'CT','Delaware': 'DE','Florida': 'FL','Georgia': 'GA','Hawaii': 'HI','Idaho': 'ID',
        'Illinois': 'IL','Indiana': 'IN','Iowa': 'IA','Kansas': 'KS','Kentucky': 'KY','Louisiana': 'LA',
        'Maine': 'ME','Maryland': 'MD','Massachusetts': 'MA','Michigan': 'MI','Minnesota': 'MN',
        'Mississippi': 'MS','Missouri': 'MO','Montana': 'MT','Nebraska': 'NE','Nevada': 'NV',
        'New Hampshire': 'NH','New Jersey': 'NJ','New Mexico': 'NM','New York': 'NY','North Carolina': 'NC',
        'North Dakota': 'ND','Ohio': 'OH','Oklahoma': 'OK','Oregon': 'OR','Pennsylvania': 'PA','Rhode Island': 'RI',
        'South Carolina': 'SC','South Dakota': 'SD','Tennessee': 'TN','Texas': 'TX','Utah': 'UT','Vermont': 'VT',
        'Virginia': 'VA','Washington': 'WA','West Virginia': 'WV','Wisconsin': 'WI','Wyoming': 'WY'
    }
    
    
    gun_df = pd.read_csv('../data/gunshot.csv')
    gun_df.insert(loc=0, column='code', value=[us_state_abbrev[i] for i in gun_df['State']])

    """    deaths = gun_df['Firearm deaths per 100,000 people']
    states = gun_df['State']"""
    return gun_df

# %%
def mental_data_fetch():
    
    import pandas as pd
    us_state_abbrev = {
        'Alabama': 'AL','Alaska': 'AK','Arizona': 'AZ','Arkansas': 'AR','California': 'CA','Colorado': 'CO',
        'Connecticut': 'CT','Delaware': 'DE','Florida': 'FL','Georgia': 'GA','Hawaii': 'HI','Idaho': 'ID',
        'Illinois': 'IL','Indiana': 'IN','Iowa': 'IA','Kansas': 'KS','Kentucky': 'KY','Louisiana': 'LA',
        'Maine': 'ME','Maryland': 'MD','Massachusetts': 'MA','Michigan': 'MI','Minnesota': 'MN',
        'Mississippi': 'MS','Missouri': 'MO','Montana': 'MT','Nebraska': 'NE','Nevada': 'NV',
        'New Hampshire': 'NH','New Jersey': 'NJ','New Mexico': 'NM','New York': 'NY','North Carolina': 'NC',
        'North Dakota': 'ND','Ohio': 'OH','Oklahoma': 'OK','Oregon': 'OR','Pennsylvania': 'PA','Rhode Island': 'RI',
        'South Carolina': 'SC','South Dakota': 'SD','Tennessee': 'TN','Texas': 'TX','Utah': 'UT','Vermont': 'VT',
        'Virginia': 'VA','Washington': 'WA','West Virginia': 'WV','Wisconsin': 'WI','Wyoming': 'WY'
    }
    
    
    mental_df = pd.read_csv('../data/mental_health.csv')
    # mental_df.insert(loc=0, column='code', value=[us_state_abbrev[i] for i in mental_df['State']])
    # we don't need this line since the csv already has the codes
    """    serious_mental = mental_df['Serious Mental Illness']
    any_mental = mental_df['Any Mental Illness']
    states = mental_df['State']
    
    serious_dict = dict(zip(states, serious_mental))
    any_dict = dict(zip(states, any_mental))"""
    
    return mental_df

# %%
gunshot_data_fetch()
# Out:
#    code           State  Firearm deaths per 100,000 people Poverty rate  \
# 0    MS     Mississippi                               19.8        20.8%
# 1    OK        Oklahoma                               19.6        16.3%
# 2    DE        Delaware                               10.9        11.7%
# 3    MN       Minnesota                                7.6         9.9%
# 4    AK          Alaska                               23.0         9.9%
# 5    IL        Illinois                               11.6        13.0%
# 6    AR        Arkansas                               17.7        17.2%
# 7    NM      New Mexico                               18.2        19.8%
# 8    OH            Ohio                               12.9        14.6%
# 9    IN         Indiana                               14.9        14.1%
# 10   MD        Maryland                               11.8         9.7%
# 11   LA       Louisiana                               21.2        20.2%
# 12   TX           Texas                               12.1        15.6%
# 13   WY         Wyoming                               17.5        11.3%
# 14   AZ         Arizona                               15.2        16.4%
# 15   WI       Wisconsin                               11.4        11.8%
# 16   MI        Michigan                               12.2        15.0%
# 17   KS          Kansas                               13.3        12.1%
# 18   UT            Utah                               12.9        10.2%
# 19   VA        Virginia                               12.0        11.0%
# 20   OR          Oregon                               11.8        13.3%
# 21   CT     Connecticut                                4.6         9.8%
# 22   TN       Tennessee                               17.0        15.8%
# 23   CA      California                                7.9        14.3%
# 24   MA   Massachusetts                                3.4        10.4%
# 25   WV   West Virginia                               17.5        17.9%
# 26   SC  South Carolina                               17.7        15.3%
# 27   NH   New Hampshire                                9.3         7.3%
# 28   VT         Vermont                               11.0        11.9%
# 29   GA         Georgia                               14.9        16.0%
# 30   ND    North Dakota                               11.9        10.7%
# 31   PA    Pennsylvania                               11.9        12.9%
# 32   FL         Florida                               12.6        14.7%
# 33   HI          Hawaii                                4.5         9.3%
# 34   KY        Kentucky                               17.5        18.5%
# 35   RI    Rhode Island                                4.0        12.8%
# 36   NE        Nebraska                                9.1        11.4%
# 37   MO        Missouri                               18.8        14.0%
# 38   IA            Iowa                                9.2        11.8%
# 39   AL         Alabama                               21.4        17.1%
# 40   SD    South Dakota                               13.5        13.3%
# 41   CO        Colorado                               14.3        11.0%
# 42   ID           Idaho                               14.6        14.4%
# 43   NJ      New Jersey                                5.5        10.4%
# 44   WA      Washington                                9.0        11.3%
# 45   NC  North Carolina                               13.6        15.4%
# 46   NY        New York                                4.4        14.7%
# 47   MT         Montana                               19.0        13.3%
# 48   NV          Nevada                               16.7        13.8%
# 49   ME           Maine                                8.2        12.5%
#
#    Permit required to carry handgun  Violent crime rate  \
# 0                                No               280.5
# 1                               Yes               449.8
# 2                               Yes               508.8
# 3                               Yes               242.6
# 4                                No               804.2
# 5                              FOID               436.3
# 6                               Yes               550.9
# 7                               Yes               702.5
# 8                               Yes               300.3
# 9                               Yes               404.7
# 10                              Yes               472.0
# 11                              Yes               566.1
# 12                              Yes               434.4
# 13                               No               244.2
# 14                               No               470.1
# 15                              Yes               305.9
# 16                              Yes               459.0
# 17                               No               380.4
# 18                              Yes               242.8
# 19                              Yes               217.6
# 20                              Yes               264.6
# 21                              Yes               227.1
# 22                              Yes               632.9
# 23                              Yes               445.3
# 24                              Yes               376.9
# 25                               No               358.1
# 26                              Yes               501.8
# 27                               No               197.6
# 28                               No               158.3
# 29                              Yes               397.6
# 30                               No               251.1
# 31                              Yes               316.4
# 32                              Yes               430.3
# 33                              Yes               309.2
# 34                              Yes               232.3
# 35                              Yes               238.9
# 36                              Yes               291.0
# 37                               No               519.4
# 38                              Yes               290.6
# 39                              Yes               532.3
# 40                              Yes               418.4
# 41                              Yes               342.6
# 42                               No               230.3
# 43                              Yes               245.0
# 44                              Yes               302.2
# 45                              Yes               372.2
# 46                              Yes               376.2
# 47                              Yes               368.3
# 48                              Yes               678.1
# 49                               No               123.8
#
#     Total firearm deaths 2016
# 0                         587
# 1                         766
# 2                         111
# 3                         432
# 4                         177
# 5                        1490
# 6                         541
# 7                         383
# 8                        1524
# 9                         997
# 10                        707
# 11                        987
# 12                       3353
# 13                        101
# 14                       1094
# 15                        664
# 16                       1230
# 17                        383
# 18                        370
# 19                       1049
# 20                        513
# 21                        172
# 22                       1148
# 23                       3184
# 24                        242
# 25                        332
# 26                        891
# 27                        132
# 28                         78
# 29                       1571
# 30                         90
# 31                       1555
# 32                       2704
# 33                         66
# 34                        772
# 35                         49
# 36                        171
# 37                       1144
# 38                        288
# 39                       1046
# 40                        108
# 41                        812
# 42                        242
# 43                        485
# 44                        686
# 45                       1409
# 46                        900
# 47                        194
# 48                        498
# 49                        123

# %%
def mapPlot(df, item):
    '''
    Generate a heatmap over the American map.
    
    :@prama df: pandas.core.frame.DataFrame, input data.
    :@param item: string, the column of the data that need to be plot.
    :@return res: plotly.tools.PlotlyDisplay, the heatmap.
    '''

    assert isinstance(df, pandas.core.frame.DataFrame), 'The input data is not a DataFrame.'
    assert isinstance(item, str), 'The input item is not a string.'
    
    
    for col in df.columns:
        df[col] = df[col].astype(str)

    scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
                [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]
    


    try:
        data = [ dict(
                type='choropleth',
                colorscale = scl,
                autocolorscale = False,
                locations = df['code'],
                z = df[item].astype(float),
                locationmode = 'USA-states',
                marker = dict(line = dict ( color = 'rgb(255,255,255)',
                                            width = 2 ) ) ) 
               ]
    except:
        raise ValueError,'Cannot convert the data in require column.'
        
        # removes commas from numbers that are strings
        """        y = df[item]    
        df.drop(columns=[item])
        df.insert(loc=3, column='Float', value = [float(i.replace(',', '')) for i in y])
        
        data = [ dict(
                type='choropleth',
                colorscale = scl,
                autocolorscale = False,
                locations = df['code'],
                z = df[item].astype(float),
                locationmode = 'USA-states',
                marker = dict(line = dict ( color = 'rgb(255,255,255)',
                                            width = 2 ) ) ) 
               ]        
        """
    layout = dict(
            title = '2016 US {}'.format(item),
            geo = dict(
                scope='usa',
                projection=dict( type='albers usa' ),
                showlakes = True,
                lakecolor = 'rgb(255, 255, 255)'),
                 )

    fig = dict( data=data, layout=layout )
    res = py.iplot( fig, filename='d3-cloropleth-map' )
    assert isinstance(res,plotly.tools.PlotlyDisplay)
    return res

# %%
plotly.tools.set_credentials_file(username='shl666', api_key='63b9Xz7eRm7yqi5GrSK2')
heatmap_deaths = mapPlot(gunshot_data_fetch(), 'Firearm deaths per 100,000 people')
heatmap_deaths
# Out:
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~shl666/0 or inside your plot.ly account where it is named 'd3-cloropleth-map'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~shl666/0.embed" height="525px" width="100%"></iframe>

# %%
import locale
import pandas as pd
def mental_to_float():
    """
    Function to convert the mental health data to float, since the commas messed stuff up
    """
    ### read data
    df_mh = pd.read_csv('../data/mental_health.csv')
    df_mh

    # way to change string with comma to float
    locale.setlocale(locale.LC_NUMERIC, '') 

    ### generate new mental health data frame
    df_mh_1 = df_mh[[[i for i in df_mh][1]]]
    df_mh_2 = df_mh[[i for i in df_mh][2:-1]].applymap(atof)### change string with comma to float
    df_mh_3 = df_mh[[[i for i in df_mh][-1]]]

    df_mh_new = pd.concat([df_mh_1,df_mh_2,df_mh_3],axis=1) ### merge
    return df_mh_new

# %%
mental_to_float()
# Out:
#    code  Serious Mental Illness  Any Mental Illness  \
# 0    AL                   156.0               680.0
# 1    AK                    24.0               105.0
# 2    AZ                   208.0               902.0
# 3    AR                   121.0               468.0
# 4    CA                  1068.0              5072.0
# 5    CO                   191.0               832.0
# 6    CT                   100.0               500.0
# 7    DE                    31.0               129.0
# 8    FL                   570.0              2769.0
# 9    GA                   315.0              1341.0
# 10   HI                    34.0               165.0
# 11   ID                    60.0               262.0
# 12   IL                   363.0              1526.0
# 13   IN                   244.0               988.0
# 14   IA                    93.0               418.0
# 15   KS                    93.0               387.0
# 16   KY                   175.0               737.0
# 17   LA                   157.0               599.0
# 18   ME                    46.0               187.0
# 19   MD                   156.0               758.0
# 20   MA                   231.0              1034.0
# 21   MI                   339.0              1320.0
# 22   MN                   177.0               759.0
# 23   MS                    86.0               385.0
# 24   MO                   192.0               828.0
# 25   MT                    43.0               164.0
# 26   NE                    58.0               258.0
# 27   NV                    93.0               404.0
# 28   NH                    53.0               204.0
# 29   NJ                   244.0              1062.0
# 30   NM                    69.0               298.0
# 31   NY                   626.0              2692.0
# 32   NC                   358.0              1440.0
# 33   ND                    23.0                97.0
# 34   OH                   453.0              1741.0
# 35   OK                   132.0               545.0
# 36   OR                   164.0               714.0
# 37   PA                   416.0              1861.0
# 38   RI                    35.0               160.0
# 39   SC                   149.0               677.0
# 40   SD                    26.0               113.0
# 41   TN                   250.0               986.0
# 42   TX                   650.0              3196.0
# 43   UT                   108.0               464.0
# 44   VT                    27.0               104.0
# 45   VA                   291.0              1261.0
# 46   WA                   264.0              1139.0
# 47   WV                    74.0               300.0
# 48   WI                   187.0               817.0
# 49   WY                    20.0                85.0
#
#     Received Mental Health Services   Had Serious Thoughts of Suicide  \
# 0                              478.0                            132.0
# 1                               71.0                             27.0
# 2                              611.0                            206.0
# 3                              346.0                            100.0
# 4                             3427.0                           1173.0
# 5                              658.0                            203.0
# 6                              473.0                            104.0
# 7                              110.0                             32.0
# 8                             2039.0                            535.0
# 9                              909.0                            298.0
# 10                              96.0                             40.0
# 11                             202.0                             59.0
# 12                            1324.0                            377.0
# 13                             761.0                            227.0
# 14                             395.0                             93.0
# 15                             303.0                            101.0
# 16                             599.0                            170.0
# 17                             462.0                            147.0
# 18                             206.0                             40.0
# 19                             624.0                            175.0
# 20                            1009.0                            212.0
# 21                            1228.0                            298.0
# 22                             794.0                            173.0
# 23                             264.0                             83.0
# 24                             721.0                            160.0
# 25                             131.0                             42.0
# 26                             223.0                             62.0
# 27                             256.0                             95.0
# 28                             218.0                             53.0
# 29                             869.0                            246.0
# 30                             201.0                             66.0
# 31                            2220.0                            605.0
# 32                            1215.0                            321.0
# 33                              82.0                             24.0
# 34                            1456.0                            394.0
# 35                             435.0                            109.0
# 36                             553.0                            160.0
# 37                            1621.0                            438.0
# 38                             157.0                             37.0
# 39                             538.0                            139.0
# 40                              95.0                             24.0
# 41                             759.0                            229.0
# 42                            2185.0                            699.0
# 43                             327.0                            117.0
# 44                             102.0                             27.0
# 45                            1045.0                            251.0
# 46                             900.0                            260.0
# 47                             244.0                             62.0
# 48                             709.0                            195.0
# 49                              61.0                             18.0
#
#     Major Depressive Episode            State
# 0                       245.0         Alabama
# 1                        39.0          Alaska
# 2                       310.0         Arizona
# 3                       181.0        Arkansas
# 4                      1786.0      California
# 5                       316.0        Colorado
# 6                       190.0     Connecticut
# 7                        48.0        Delaware
# 8                       979.0         Florida
# 9                       508.0         Georgia
# 10                       57.0          Hawaii
# 11                       92.0           Idaho
# 12                      545.0        Illinois
# 13                      381.0         Indiana
# 14                      158.0            Iowa
# 15                      154.0          Kansas
# 16                      252.0        Kentucky
# 17                      225.0       Louisiana
# 18                       76.0           Maine
# 19                      307.0        Maryland
# 20                      400.0   Massachusetts
# 21                      521.0        Michigan
# 22                      292.0       Minnesota
# 23                      133.0     Mississippi
# 24                      321.0        Missouri
# 25                       62.0         Montana
# 26                       98.0        Nebraska
# 27                      162.0          Nevada
# 28                       84.0   New Hampshire
# 29                      421.0      New Jersey
# 30                      104.0      New Mexico
# 31                     1026.0        New York
# 32                      536.0  North Carolina
# 33                       39.0    North Dakota
# 34                      693.0            Ohio
# 35                      216.0        Oklahoma
# 36                      249.0          Oregon
# 37                      677.0    Pennsylvania
# 38                       60.0    Rhode Island
# 39                      243.0  South Carolina
# 40                       43.0    South Dakota
# 41                      355.0       Tennessee
# 42                     1132.0           Texas
# 43                      162.0            Utah
# 44                       38.0         Vermont
# 45                      501.0        Virginia
# 46                      422.0      Washington
# 47                      118.0   West Virginia
# 48                      298.0       Wisconsin
# 49                       33.0         Wyoming

# %%
import pandas

def alphabetize(gun_df, gun_item):
    """
    Puts gun_df[gun_item] in alphabetical order by State for our correlation test, 
    and returns it as a list that is in alphabetical order by respective state. 
    """
    gun = list(gun_df[gun_item])
    gun_state_order = list(gun_df['State'])
    gun, gun_state_order = zip(*sorted(zip(gun_state_order, gun)))

    return gun_state_order

# %%
def correlation(gun_df, mental_df, gun_item, mental_item):
    """
    Correlates 2 sets of pandas data columns, columns are specified by gun_item and mental_item
    """
    import scipy
    from scipy.stats import pearsonr
    
    assert isinstance(gun_item,str)
    assert isinstance(mental_item, str)
    
    gun = gun_df[gun_item].astype(float)
    mental = mental_df[mental_item]
    #no need to use astype since our function converted all the values to float

    #gun is not in alphabetical order
    #mental is in alphabetical order
    alph_gun = alphabetize(gun_df, gun_item)
    print list(alph_gun)
    print list(mental)
    coef = pearsonr(list(alph_gun), list(mental))
    return coef

# %%
correlation(gunshot_data_fetch(), mental_to_float(), 'Firearm deaths per 100,000 people', 'Serious Mental Illness')
# Out:
# [21.4, 23.0, 15.2, 17.7, 7.9, 14.3, 4.6, 10.9, 12.6, 14.9, 4.5, 14.6, 11.6, 14.9, 9.2, 13.3, 17.5, 21.2, 8.2, 11.8, 3.4, 12.2, 7.6, 19.8, 18.8, 19.0, 9.1, 16.7, 9.3, 5.5, 18.2, 4.4, 13.6, 11.9, 12.9, 19.6, 11.8, 11.9, 4.0, 17.7, 13.5, 17.0, 12.1, 12.9, 11.0, 12.0, 9.0, 17.5, 11.4, 17.5]
# [156.0, 24.0, 208.0, 121.0, 1068.0, 191.0, 100.0, 31.0, 570.0, 315.0, 34.0, 60.0, 363.0, 244.0, 93.0, 93.0, 175.0, 157.0, 46.0, 156.0, 231.0, 339.0, 177.0, 86.0, 192.0, 43.0, 58.0, 93.0, 53.0, 244.0, 69.0, 626.0, 358.0, 23.0, 453.0, 132.0, 164.0, 416.0, 35.0, 149.0, 26.0, 250.0, 650.0, 108.0, 27.0, 291.0, 264.0, 74.0, 187.0, 20.0]
# (-0.22275072756879696, 0.11998080903203469)
